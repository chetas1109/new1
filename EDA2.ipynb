# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
##Read Data set and see top and bottom rows to have quick glimpse of data
df=pd.read_csv("Automobile_data.csv")

# %%
df.head(1)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
#
#   highway-mpg  price
# 0          27  13495
#
# [1 rows x 26 columns]

# %%
df.tail(3)
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 202      sedan          rwd           front       109.1  ...          173
# 203      sedan          rwd           front       109.1  ...          145
# 204      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 202         mpfi  3.58    2.87               8.8        134      5500
# 203          idi  3.01     3.4              23.0        106      4800
# 204         mpfi  3.78    3.15               9.5        114      5400
#
#     city-mpg highway-mpg  price
# 202       18          23  21485
# ...

# %%
##Get shape of data to understand number of observations
df.shape
# Out:
# (205, 26)

# %%
##Get Feature names of dataset
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
print(len(df.columns))
# Out:
# 26

# %%
df.keys()
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
##Get full Decription/summary of dataset
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
#######

# %%
###Understand the data types of Dataset and downgrade its type to save memory
### its very lengthy step plz.avoide
'''
print(df.symboling.unique())
#print(df.normalized-losses.unique())
print(df.make.unique())
#print(df.fuel-type.unique())
print(df.aspiration.unique())
#print(df.num-of-doors.unique())
#print(df.body-style.unique())
#print(df.drive-wheels.unique())
#print(df.engine-location.unique())
#print(df.wheel-base.unique())
print(df.length.unique())
print(df.width.unique())
print(df.height.unique())
#print(df.curb-weight.unique())
#print(df.engine-type.unique())
#print(df.num-of-cylinders.unique())
#print(df.engine-size.unique())
print(df.price.unique())
##print(df.highway-mpg.unique())
#print(df.city-mpg.unique())
#print(df.peak-rpm.unique())
print(df.horsepower.unique())
#print(df.compression-ratio.unique())
print(df.stroke.unique())
print(df.bore.unique())
#print(df.fuel-system.unique())
'''
# Out:
# '\nprint(df.symboling.unique())\n#print(df.normalized-losses.unique())\nprint(df.make.unique())\n#print(df.fuel-type.unique())\nprint(df.aspiration.unique())\n#print(df.num-of-doors.unique())\n#print(df.body-style.unique())\n#print(df.drive-wheels.unique())\n#print(df.engine-location.unique())\n#print(df.wheel-base.unique())\nprint(df.length.unique())\nprint(df.width.unique())\nprint(df.height.unique())\n#print(df.curb-weight.unique())\n#print(df.engine-type.unique())\n#print(df.num-of-cylinders.unique())\n#print(df.engine-size.unique())\nprint(df.price.unique())\n##print(df.highway-mpg.unique())\n#print(df.city-mpg.unique())\n#print(df.peak-rpm.unique())\nprint(df.horsepower.unique())\n#print(df.compression-ratio.unique())\nprint(df.stroke.unique())\nprint(df.bore.unique())\n#print(df.fuel-system.unique())\n'

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
#### there is no null value but thers is unique value present or not we have to identify

# %%
##Get unique values for each feature, this will help you to get to know if any unwanted characters are present in dataset
for k in df.keys():
    print(k,df[k].unique()) ### will give all unique value of df
# Out:
# symboling [ 3  1  2  0 -1 -2]
# normalized-losses ['?' '164' '158' '192' '188' '121' '98' '81' '118' '148' '110' '145' '137'
#  '101' '78' '106' '85' '107' '104' '113' '150' '129' '115' '93' '142'
#  '161' '153' '125' '128' '122' '103' '168' '108' '194' '231' '119' '154'
#  '74' '186' '83' '102' '89' '87' '77' '91' '134' '65' '197' '90' '94'
#  '256' '95']
# make ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'mercedes-benz' 'mercury' 'mitsubishi' 'nissan' 'peugot'
#  'plymouth' 'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen'
#  'volvo']
# fuel-type ['gas' 'diesel']
# aspiration ['std' 'turbo']
# num-of-doors ['two' 'four' '?']
# body-style ['convertible' 'hatchback' 'sedan' 'wagon' 'hardtop']
# drive-wheels ['rwd' 'fwd' '4wd']
# engine-location ['front' 'rear']
# wheel-base [ 88.6  94.5  99.8  99.4 105.8  99.5 101.2 103.5 110.   88.4  93.7 103.3
#   95.9  86.6  96.5  94.3  96.  113.  102.   93.1  95.3  98.8 104.9 106.7
# ...

# %%
df=="?"
# Out:
#      symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0        False               True  False      False       False         False
# 1        False               True  False      False       False         False
# 2        False               True  False      False       False         False
# 3        False              False  False      False       False         False
# 4        False              False  False      False       False         False
# ..         ...                ...    ...        ...         ...           ...
# 200      False              False  False      False       False         False
# 201      False              False  False      False       False         False
# 202      False              False  False      False       False         False
# 203      False              False  False      False       False         False
# 204      False              False  False      False       False         False
#
# ...

# %%
(df=="?").sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
plt.figure(figsize=(16,4))  ## will represent the "?" value
sns.heatmap(df=="?",cmap="winter")
plt.show()

# %%
for k in df.keys():
    if "?" in df[k].unique():
        df[k]=df[k].replace("?",np.nan)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6172\3078166605.py:2: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if "?" in df[k].unique():

# %%
df.head(3)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
#
#   highway-mpg  price
# ...

# %%
##  check further for assurity
plt.figure(figsize=(16,4))  ## will represent the "?" value
sns.heatmap(df=="?",cmap="winter")
plt.show()

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
########## fill misssing value with fill na
df["num-of-doors"].mode()[0]
# Out:
# 'four'

# %%
df["num-of-doors"]=df["num-of-doors"].fillna(df["num-of-doors"].mode()[0])

# %%
df["price"].median()
# Out:
# 10295.0

# %%
df["price"]=df["price"].fillna(df["price"].median())

# %%
df["peak-rpm"].mode()[0]
# Out:
# '5500'

# %%
df["peak-rpm"]=df["peak-rpm"].fillna(df["peak-rpm"].mode()[0])

# %%
df["horsepower"].median()
# Out:
# 95.0

# %%
df["horsepower"]=df["horsepower"].fillna(df["horsepower"].median())

# %%
df["bore"].mode()[0]
# Out:
# '3.62'

# %%
df["bore"]=df["bore"].fillna(df["bore"].mode()[0])

# %%
df["stroke"].mode()[0]
# Out:
# '3.4'

# %%
df["stroke"]=df["stroke"].fillna(df["stroke"].mode()[0])

# %%
df["normalized-losses"].mode()[0]
# Out:
# '161'

# %%
df["normalized-losses"]=df["normalized-losses"].fillna(df["normalized-losses"].mode()[0])

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
############type casting because column contail value and dtype given object for that we do tycasting
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
##float 64
for k in df.keys():
    if "float" in str(df[k].dtype):
        df[k]=df[k].astype("float16")

# %%
df["compression-ratio"].dtype
# Out:
# dtype('float16')

# %%
##int=64
for k in df.keys():
    if "int" in str(df[k].dtype) and df[k].max() <=200:
        df[k]=df[k].astype("int8")
    if "int" in str(df[k].dtype) and df[k].max() >=200:
        df[k]=df[k].astype("int16")

# %%
df["engine-size"].dtype
# Out:
# dtype('int16')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int8
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float16
#  10  length             205 non-null    float16
#  11  width              205 non-null    float16
#  12  height             205 non-null    float16
#  13  curb-weight        205 non-null    int16
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
corr=df.corr()
corr
# Out:
#                    symboling  wheel-base    length     width    height  \
# symboling           1.000000   -0.531816 -0.356811 -0.231642 -0.541832
# wheel-base         -0.531816    1.000000  0.874847  0.795329  0.589862
# length             -0.356811    0.874847  1.000000  0.841193  0.490902
# width              -0.231642    0.795329  0.841193  1.000000  0.278012
# height             -0.541832    0.589862  0.490902  0.278012  1.000000
# curb-weight        -0.227691    0.776465  0.877967  0.867735  0.295280
# engine-size        -0.105790    0.569298  0.683517  0.737239  0.067106
# compression-ratio  -0.178600    0.249670  0.158328  0.180938  0.261172
# city-mpg           -0.035823   -0.470673 -0.671103 -0.643334 -0.048238
# highway-mpg         0.034606   -0.544282 -0.704866 -0.677622 -0.107059
#
#                    curb-weight  engine-size  compression-ratio  city-mpg  \
# symboling            -0.227691    -0.105790          -0.178600 -0.035823
# ...

# %%
plt.figure(figsize=(16,4))
sns.heatmap(corr,annot= True)
# Out:
# <AxesSubplot:>

# %%
df.head(1)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               161  alfa-romero       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front      88.625  ...          130
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
#
#   highway-mpg  price
# 0          27  13495
#
# [1 rows x 26 columns]

# %%
plt.figure(figsize=(16,4))
sns.countplot(df.make,hue=df.aspiration)
# Out:
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='make', ylabel='count'>

# %%
sns.histplot(df["num-of-doors"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [88], in <module>
# ----> 1 sns.histplot(df["num-of-doors"],hue=df["make"])
#
# File c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:1430, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1409 def histplot(
#    1410     data=None, *,
#    1411     # Vector variables
#    (...)
#    1427     **kwargs,
#    1428 ):
# -> 1430     p = _DistributionPlotter(
#    1431         data=data,
#    1432         variables=_DistributionPlotter.get_semantics(locals())
#    1433     )
# ...

# %%
plt.figure(figsize=(16,4))
sns.histplot(df.make)
# Out:
# <AxesSubplot:xlabel='make', ylabel='Count'>

# %%
plt.figure(figsize=(16,4))
sns.histplot(df.aspiration)
# Out:
# <AxesSubplot:xlabel='aspiration', ylabel='Count'>

# %%
sns.pairplot(df,hue="aspiration")

# %%
sns.kdeplot(df["engine-size"],hue=df["aspiration"])
# Out:
# <AxesSubplot:xlabel='engine-size', ylabel='Density'>

# %%
sns.kdeplot(df["wheel-base"],hue=df["engine-size"])
# Out:
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
# ...

# %%
sns.kdeplot(df["compression-ratio"],hue=df["fuel-type"])
# Out:
# <AxesSubplot:xlabel='compression-ratio', ylabel='Density'>

# %%
plt.figure(figsize=(16,4))
sns.countplot(df["drive-wheels"])
plt.xticks(rotation=90)
plt.show()
# Out:
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.make.value_counts().plot(kind="barh",figsize=(16,4),color="r")
# Out:
# <AxesSubplot:>
